# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('../data/ar_properties.csv')
df
# Out:
#                               id    ad_type  start_date    end_date  \
# 0       7LoZFkSIPOTox0r32ck42Q==  Propiedad  2019-09-15  2019-10-26
# 1       QsZD4OxZInNd5po5LQDRmg==  Propiedad  2019-09-15  9999-12-31
# 2       qDtysoUgbnHLp0W9We+8fg==  Propiedad  2019-09-15  2019-09-25
# 3       olj51zV0HFurmaZ78U0ssg==  Propiedad  2019-09-15  2019-09-25
# 4       OcS1SAA5oAzjZ3Mzg3XHyg==  Propiedad  2019-09-15  2019-09-25
# ...                          ...        ...         ...         ...
# 999995  ml17bb3zNa945e9dZWrJ6Q==  Propiedad  2020-02-20  2020-04-28
# 999996  O54TyNw4kMogEjaJqWhtLw==  Propiedad  2020-02-20  2020-04-28
# 999997  Y1K0Rl31ib5DwJL5qqCiqg==  Propiedad  2020-02-20  2020-04-28
# 999998  xZ+W9ufh1Ugj2jPPqWwN8A==  Propiedad  2020-02-20  2020-04-28
# 999999  ltEpAbgzrzhM2pMIKtfHNg==  Propiedad  2020-02-20  2020-04-28
#
#         created_on        lat        lon         l1  \
# 0       2019-09-15 -26.815439 -65.312393  Argentina
# 1       2019-09-15 -26.839469 -65.212790  Argentina
# 2       2019-09-15 -31.424820 -64.181225  Argentina
# 3       2019-09-15 -31.421242 -64.190798  Argentina
# 4       2019-09-15 -31.426064 -64.180042  Argentina
# ...            ...        ...        ...        ...
# 999995  2020-02-20 -38.011919 -57.535854  Argentina
# 999996  2020-02-20 -37.995254 -57.553228  Argentina
# 999997  2020-02-20 -37.983723 -57.544284  Argentina
# 999998  2020-02-20 -32.983590 -68.879191  Argentina
# 999999  2020-02-20 -37.940854 -57.779998  Argentina
#
#                                   l2                  l3  ... bathrooms  \
# 0                            Tucumán         Yerba Buena  ...       NaN
# 1                            Tucumán                 NaN  ...       1.0
# 2                            Córdoba             Córdoba  ...       1.0
# 3                            Córdoba             Córdoba  ...       1.0
# 4                            Córdoba             Córdoba  ...       1.0
# ...                              ...                 ...  ...       ...
# 999995  Buenos Aires Costa Atlántica       Mar del Plata  ...       5.0
# 999996  Buenos Aires Costa Atlántica       Mar del Plata  ...       5.0
# 999997  Buenos Aires Costa Atlántica       Mar del Plata  ...       5.0
# 999998                       Mendoza      Cuadro Benegas  ...       5.0
# 999999         Buenos Aires Interior  General Pueyrredón  ...       5.0
#
#        surface_total  surface_covered     price  currency  price_period  \
# 0                NaN              NaN       NaN       NaN       Mensual
# 1               55.0             41.0       NaN       NaN       Mensual
# 2               45.0             45.0       NaN       NaN       Mensual
# 3               48.0             48.0       NaN       NaN       Mensual
# 4               45.0             45.0       NaN       NaN       Mensual
# ...              ...              ...       ...       ...           ...
# 999995           NaN              NaN  750000.0       USD           NaN
# 999996           NaN              NaN  180000.0       USD           NaN
# 999997           NaN              NaN  450000.0       USD           NaN
# 999998           NaN              NaN  500000.0       USD           NaN
# 999999           NaN              NaN  250000.0       USD           NaN
#
#                                            title  \
# 0                          Terreno - Yerba Buena
# 1                         Departamento - Capital
# 2              1 DORMITORIO | San Lorenzo al 400
# 3          1 DORMITORIO | M. T. de Alvear al 500
# 4       1 DORMITORIO | Av. Poeta Lugones  al 200
# ...                                          ...
# 999995                      CHALET  STELLA MARIS
# 999996       Venta Dto 4 Amb con Dep Macrocentro
# 999997     UNICA - HISTORICA - destino comercial
# 999998            CASA EN VENTA-CHACRAS DE CORIA
# 999999  salon de fiestas en Sierra de los Padres
#
#                                               description  property_type  \
# 0       Accesos pavimentados.<br>Red subterránea de ag...           Lote
# 1       Detalles constructivos:<br><br>Pisos de porcel...   Departamento
# 2       Alquiler temporario de Departamento 1 DORMITOR...   Departamento
# 3       Alquiler temporario de Departamento 1 DORMITOR...   Departamento
# 4       Alquiler temporario de Departamento 1 DORMITOR...   Departamento
# ...                                                   ...            ...
# 999995  Chalet en dos plantas sobre lote de 1100 m2 y ...           Otro
# 999996  En av.  Luro esquina Salta encontramos este am...           Otro
# 999997  IDEAL DESARROLLO COMERCIAL - Pegado al Unzue -...           Otro
# 999998  Importante propiedad en calle Italia, Chacras ...           Otro
# 999999  Salon de eventos con capacidad para 80 persona...           Otro
#
#            operation_type
# 0                   Venta
# 1                   Venta
# 2       Alquiler temporal
# 3       Alquiler temporal
# 4       Alquiler temporal
# ...                   ...
# 999995              Venta
# 999996              Venta
# 999997              Venta
# 999998              Venta
# 999999              Venta
#
# [1000000 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['id', 'ad_type', 'start_date', 'end_date', 'created_on', 'lat', 'lon',
#        'l1', 'l2', 'l3', 'l4', 'l5', 'l6', 'rooms', 'bedrooms', 'bathrooms',
#        'surface_total', 'surface_covered', 'price', 'currency', 'price_period',
#        'title', 'description', 'property_type', 'operation_type'],
#       dtype='object')

# %%
def detect_column_types(df, categorical_threshold=10):
    numeric_cols = df.select_dtypes(include=['number']).columns
    categorical_cols = [col for col in df.select_dtypes(include=['object']).columns
                        if df[col].nunique() < categorical_threshold]
    date_cols = []
    for col in df.select_dtypes(include=['object']).columns:
        try:
            pd.to_datetime(df[col])
            date_cols.append(col)
        except (ValueError, TypeError):
            continue
    
    return numeric_cols, categorical_cols, date_cols

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class MultiDateFeatureExtractor(BaseEstimator, TransformerMixin):
    def __init__(self, columns=None):
        self.columns = columns
    
    def fit(self, X, y=None):
        return self

    def transform(self, X):
        for column in self.columns:
            # Ensure each date column is a datetime type
            X[column] = pd.to_datetime(X[column])
            # Extract features for each date column
            X[f'{column}_year'] = X[column].dt.year
            X[f'{column}_month'] = X[column].dt.month
            X[f'{column}_day'] = X[column].dt.day
            X[f'{column}_day_of_week'] = X[column].dt.dayofweek

        return X.drop(columns=self.columns)

# %%
df
# Out:
#                               id    ad_type  start_date    end_date  \
# 0       7LoZFkSIPOTox0r32ck42Q==  Propiedad  2019-09-15  2019-10-26
# 1       QsZD4OxZInNd5po5LQDRmg==  Propiedad  2019-09-15  9999-12-31
# 2       qDtysoUgbnHLp0W9We+8fg==  Propiedad  2019-09-15  2019-09-25
# 3       olj51zV0HFurmaZ78U0ssg==  Propiedad  2019-09-15  2019-09-25
# 4       OcS1SAA5oAzjZ3Mzg3XHyg==  Propiedad  2019-09-15  2019-09-25
# ...                          ...        ...         ...         ...
# 999995  ml17bb3zNa945e9dZWrJ6Q==  Propiedad  2020-02-20  2020-04-28
# 999996  O54TyNw4kMogEjaJqWhtLw==  Propiedad  2020-02-20  2020-04-28
# 999997  Y1K0Rl31ib5DwJL5qqCiqg==  Propiedad  2020-02-20  2020-04-28
# 999998  xZ+W9ufh1Ugj2jPPqWwN8A==  Propiedad  2020-02-20  2020-04-28
# 999999  ltEpAbgzrzhM2pMIKtfHNg==  Propiedad  2020-02-20  2020-04-28
#
#         created_on        lat        lon         l1  \
# 0       2019-09-15 -26.815439 -65.312393  Argentina
# 1       2019-09-15 -26.839469 -65.212790  Argentina
# 2       2019-09-15 -31.424820 -64.181225  Argentina
# 3       2019-09-15 -31.421242 -64.190798  Argentina
# 4       2019-09-15 -31.426064 -64.180042  Argentina
# ...            ...        ...        ...        ...
# 999995  2020-02-20 -38.011919 -57.535854  Argentina
# 999996  2020-02-20 -37.995254 -57.553228  Argentina
# 999997  2020-02-20 -37.983723 -57.544284  Argentina
# 999998  2020-02-20 -32.983590 -68.879191  Argentina
# 999999  2020-02-20 -37.940854 -57.779998  Argentina
#
#                                   l2                  l3  ... bathrooms  \
# 0                            Tucumán         Yerba Buena  ...       NaN
# 1                            Tucumán                 NaN  ...       1.0
# 2                            Córdoba             Córdoba  ...       1.0
# 3                            Córdoba             Córdoba  ...       1.0
# 4                            Córdoba             Córdoba  ...       1.0
# ...                              ...                 ...  ...       ...
# 999995  Buenos Aires Costa Atlántica       Mar del Plata  ...       5.0
# 999996  Buenos Aires Costa Atlántica       Mar del Plata  ...       5.0
# 999997  Buenos Aires Costa Atlántica       Mar del Plata  ...       5.0
# 999998                       Mendoza      Cuadro Benegas  ...       5.0
# 999999         Buenos Aires Interior  General Pueyrredón  ...       5.0
#
#        surface_total  surface_covered     price  currency  price_period  \
# 0                NaN              NaN       NaN       NaN       Mensual
# 1               55.0             41.0       NaN       NaN       Mensual
# 2               45.0             45.0       NaN       NaN       Mensual
# 3               48.0             48.0       NaN       NaN       Mensual
# 4               45.0             45.0       NaN       NaN       Mensual
# ...              ...              ...       ...       ...           ...
# 999995           NaN              NaN  750000.0       USD           NaN
# 999996           NaN              NaN  180000.0       USD           NaN
# 999997           NaN              NaN  450000.0       USD           NaN
# 999998           NaN              NaN  500000.0       USD           NaN
# 999999           NaN              NaN  250000.0       USD           NaN
#
#                                            title  \
# 0                          Terreno - Yerba Buena
# 1                         Departamento - Capital
# 2              1 DORMITORIO | San Lorenzo al 400
# 3          1 DORMITORIO | M. T. de Alvear al 500
# 4       1 DORMITORIO | Av. Poeta Lugones  al 200
# ...                                          ...
# 999995                      CHALET  STELLA MARIS
# 999996       Venta Dto 4 Amb con Dep Macrocentro
# 999997     UNICA - HISTORICA - destino comercial
# 999998            CASA EN VENTA-CHACRAS DE CORIA
# 999999  salon de fiestas en Sierra de los Padres
#
#                                               description  property_type  \
# 0       Accesos pavimentados.<br>Red subterránea de ag...           Lote
# 1       Detalles constructivos:<br><br>Pisos de porcel...   Departamento
# 2       Alquiler temporario de Departamento 1 DORMITOR...   Departamento
# 3       Alquiler temporario de Departamento 1 DORMITOR...   Departamento
# 4       Alquiler temporario de Departamento 1 DORMITOR...   Departamento
# ...                                                   ...            ...
# 999995  Chalet en dos plantas sobre lote de 1100 m2 y ...           Otro
# 999996  En av.  Luro esquina Salta encontramos este am...           Otro
# 999997  IDEAL DESARROLLO COMERCIAL - Pegado al Unzue -...           Otro
# 999998  Importante propiedad en calle Italia, Chacras ...           Otro
# 999999  Salon de eventos con capacidad para 80 persona...           Otro
#
#            operation_type
# 0                   Venta
# 1                   Venta
# 2       Alquiler temporal
# 3       Alquiler temporal
# 4       Alquiler temporal
# ...                   ...
# 999995              Venta
# 999996              Venta
# 999997              Venta
# 999998              Venta
# 999999              Venta
#
# [1000000 rows x 25 columns]

# %%
df1 = df[:]
df1 = df1[df1['price_period']=='Mensual']
df1 = df1[['id', 'ad_type', 'start_date', 'end_date', 'created_on', 'lat', 'lon',
       'l1', 'l2', 'l3', 'l4', 'l5', 'l6', 'rooms', 'bedrooms', 'bathrooms',
       'surface_total', 'surface_covered', 'price', 'currency', 'price_period',
       'title', 'description', 'property_type', 'operation_type']]
df1.drop('price_period', inplace=True, axis=1)
df1
# Out:
#                               id    ad_type  start_date    end_date  \
# 0       7LoZFkSIPOTox0r32ck42Q==  Propiedad  2019-09-15  2019-10-26
# 1       QsZD4OxZInNd5po5LQDRmg==  Propiedad  2019-09-15  9999-12-31
# 2       qDtysoUgbnHLp0W9We+8fg==  Propiedad  2019-09-15  2019-09-25
# 3       olj51zV0HFurmaZ78U0ssg==  Propiedad  2019-09-15  2019-09-25
# 4       OcS1SAA5oAzjZ3Mzg3XHyg==  Propiedad  2019-09-15  2019-09-25
# ...                          ...        ...         ...         ...
# 999961  AK9MeeUjjWmqYjlDZrbDCg==  Propiedad  2020-02-20  2020-02-20
# 999962  hxECKr/KuZYItA9PitlIpA==  Propiedad  2020-02-20  2020-02-20
# 999963  n0aAlxYzsgk0AZXK9m4+4Q==  Propiedad  2020-02-20  2020-02-20
# 999964  unb7EtLHHs/tr5gLETZSxg==  Propiedad  2020-02-20  2020-02-21
# 999972  eV8lXCKHeVhgJJT6iIcNAQ==  Propiedad  2020-02-20  9999-12-31
#
#         created_on        lat        lon         l1               l2  \
# 0       2019-09-15 -26.815439 -65.312393  Argentina          Tucumán
# 1       2019-09-15 -26.839469 -65.212790  Argentina          Tucumán
# 2       2019-09-15 -31.424820 -64.181225  Argentina          Córdoba
# 3       2019-09-15 -31.421242 -64.190798  Argentina          Córdoba
# 4       2019-09-15 -31.426064 -64.180042  Argentina          Córdoba
# ...            ...        ...        ...        ...              ...
# 999961  2020-02-20 -34.553085 -58.439111  Argentina  Capital Federal
# 999962  2020-02-20 -34.562910 -58.447737  Argentina  Capital Federal
# 999963  2020-02-20 -34.567504 -58.458643  Argentina  Capital Federal
# 999964  2020-02-20 -34.618343 -58.370165  Argentina  Capital Federal
# 999972  2020-02-20 -32.212425 -58.159485  Argentina       Entre Ríos
#
#                  l3  ... bedrooms bathrooms  surface_total  surface_covered  \
# 0       Yerba Buena  ...      NaN       NaN            NaN              NaN
# 1               NaN  ...      NaN       1.0           55.0             41.0
# 2           Córdoba  ...      NaN       1.0           45.0             45.0
# 3           Córdoba  ...      NaN       1.0           48.0             48.0
# 4           Córdoba  ...      NaN       1.0           45.0             45.0
# ...             ...  ...      ...       ...            ...              ...
# 999961     Belgrano  ...      4.0       5.0          257.0            227.0
# 999962     Belgrano  ...      3.0       5.0          161.0            151.0
# 999963     Belgrano  ...      4.0       5.0          351.0            230.0
# 999964    San Telmo  ...      NaN       5.0            NaN              NaN
# 999972        Colón  ...      NaN       5.0        15000.0            400.0
#
#             price  currency  \
# 0             NaN       NaN
# 1             NaN       NaN
# 2             NaN       NaN
# 3             NaN       NaN
# 4             NaN       NaN
# ...           ...       ...
# 999961     6000.0       USD
# 999962     3500.0       USD
# 999963   680000.0       USD
# 999964  1550000.0       USD
# 999972        NaN       NaN
#
#                                                     title  \
# 0                                   Terreno - Yerba Buena
# 1                                  Departamento - Capital
# 2                       1 DORMITORIO | San Lorenzo al 400
# 3                   1 DORMITORIO | M. T. de Alvear al 500
# 4                1 DORMITORIO | Av. Poeta Lugones  al 200
# ...                                                   ...
# 999961  ESPECTACULAR TORRE FORUM ALCORTA PISO ALTO - P...
# 999962  TOWN HOUSE BARRANCAS - ÚNICO - PARQUE 3700 M2 !!!
# 999963  VENTA - 5 AMB. CON 3 COCH. BAULERA Y PATIO - B...
# 999964                 Venta en  San Telmo - Balcarce 900
# 999972  Zona Artalaz  100 - Consulte precio - Hotel en...
#
#                                               description  property_type  \
# 0       Accesos pavimentados.<br>Red subterránea de ag...           Lote
# 1       Detalles constructivos:<br><br>Pisos de porcel...   Departamento
# 2       Alquiler temporario de Departamento 1 DORMITOR...   Departamento
# 3       Alquiler temporario de Departamento 1 DORMITOR...   Departamento
# 4       Alquiler temporario de Departamento 1 DORMITOR...   Departamento
# ...                                                   ...            ...
# 999961  Increíble Departamento de 5 Ambientes con Balc...   Departamento
# 999962  TORRE ÚNICA E IRREPETIBLE!!!  - EN EL CORAZÓN ...   Departamento
# 999963  ******ESPECTACULAR DÚPLEX EN EXCLUSIVA ZONA RE...   Departamento
# 999964  Casa de 7 ambientes en San Telmo Living comedo...           Otro
# 999972  Reconocido complejo turístico de Colón en vent...           Otro
#
#            operation_type
# 0                   Venta
# 1                   Venta
# 2       Alquiler temporal
# 3       Alquiler temporal
# 4       Alquiler temporal
# ...                   ...
# 999961           Alquiler
# 999962           Alquiler
# 999963              Venta
# 999964              Venta
# 999972              Venta
#
# [418757 rows x 24 columns]

# %%
df1.isna().sum().sort_values(ascending=False)
# Out:
# l6                 418757
# l5                 416952
# bedrooms           312571
# l4                 309336
# rooms              186291
# surface_total      161180
# surface_covered    158552
# bathrooms           94969
# lon                 46715
# lat                 46688
# currency            44046
# price               38215
# l3                  22578
# title                  28
# description            21
# property_type           0
# id                      0
# ad_type                 0
# l2                      0
# l1                      0
# created_on              0
# end_date                0
# start_date              0
# operation_type          0
# dtype: int64

# %%
df1 = df1.drop(['l6', 'l5', 'bedrooms', 'l4'], axis=1)

# %%
df1 = df1[df1['currency']=='USD']
df1 = df1.dropna()

# %%
X = df1.drop("price", axis=1)
y = df1['price']

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.pipeline import Pipeline

numerical_features, categorical_features, date_columns = detect_column_types(X)
print("Numeric Columns:", numeric)
print("Categorical Columns:", categorical)
print("Date Columns:", date)

preprocessor = ColumnTransformer(
    transformers=[
        ('num', MinMaxScaler(), numerical_features),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features),
        ('date', MultiDateFeatureExtractor(columns=date_columns), date_columns)
    ])
# Out:
# Numeric Columns: Index(['lat', 'lon', 'l6', 'rooms', 'bedrooms', 'bathrooms', 'surface_total',
#        'surface_covered', 'price'],
#       dtype='object')
# Categorical Columns: ['ad_type', 'l1', 'currency', 'price_period', 'operation_type']
# Date Columns: ['start_date', 'created_on']

# %%
pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                           ('estimator', LinearRegression())])

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', MinMaxScaler(),
#                                                   Index(['lat', 'lon', 'rooms', 'bathrooms', 'surface_total', 'surface_covered'], dtype='object')),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['ad_type', 'l1', 'currency',
#                                                    'operation_type']),
#                                                  ('date',
#                                                   MultiDateFeatureExtractor(columns=['start_date',
#                                                                                      'created_on']),
#                                                   ['start_date',
#                                                    'created_on'])])),
#                 ('estimator', LinearRegression())])

# %%
y_pred = pipeline.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score
print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
print("R² Score:", r2_score(y_test, y_pred))
# Out:
# Mean Squared Error: 63152863007.52336
# R² Score: 0.29710572173437433
